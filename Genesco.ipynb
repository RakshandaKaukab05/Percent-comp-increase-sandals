# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_columns',104)
import seaborn as sns
import pandas_profiling

# %matplotlib inline

# %%
store_df = pd.read_csv('0826export.csv')
store_df.head()
# Out:
#    DIV  STORE WEEK_END_DATE  FISCAL_YEAR  FISCAL_WEEK  FISCAL_MONTH  \
# 0    7   1504     06-FEB-16         2017            1             1
# 1    7   1504     13-FEB-16         2017            2             1
# 2    7   1504     20-FEB-16         2017            3             1
# 3    7   1504     27-FEB-16         2017            4             1
# 4    7   1504     05-MAR-16         2017            5             2
#
#    SALES_AMT_TY  SALES_AMT_LY  COMP_PCT  FISCAL_YEAR_LY  FISCAL_WEEK_LY  \
# 0      22003.18      21266.87  0.034622            2016               1
# 1      17499.35      23490.64 -0.255050            2016               2
# 2      15004.60      22318.80 -0.327715            2016               3
# 3      12770.09      17296.40 -0.261691            2016               4
# 4      19920.51      24553.82 -0.188700            2016               5
#
#    FISCAL_MONTH_LY WEEK_END_DATE_LY  MARK_DOWN_AMT_TY  MARK_DOWN_AMT_LY  \
# ...

# %%
sales =store_df.groupby('FISCAL_MONTH')

# %%
shoes = sales[['COMP_PCT','SHOES_VALUE']]

# %%
aggregated = shoes.agg(['max','median'])
aggregated
# Out:
#                 COMP_PCT           SHOES_VALUE
#                      max    median         max     median
# FISCAL_MONTH
# 1               3.342601  0.029918    36337.73  10176.750
# 2               2.314969  0.007008    48427.61  11134.940
# 3               3.135850 -0.001097    52293.38  11181.720
# 4               4.245985  0.011309    54501.36  11433.605
# 5               3.540078  0.013546    59227.56  10649.190
# 6             245.175193  0.006814    45424.85   9396.205
# 7              20.424050  0.013999    41073.75   9929.720
# 8               5.554588  0.021217    49859.03  10387.360
# 9               5.506788  0.026829    45660.05  11490.760
# 10              2.905029  0.018619    61874.31  12683.740
# 11              1.143600  0.004427    67052.89  15051.875
# 12              6.630358  0.014411    49960.06   9914.560

# %%
store_df.COMP_PCT.mean()
# Out:
# 0.05896915676828596

# %%
store_df.nlargest(20, "COMP_PCT")
# Out:
#        DIV  STORE WEEK_END_DATE  FISCAL_YEAR  FISCAL_WEEK  FISCAL_MONTH  \
# 26686    7   2084     23-JUL-16         2017           25             6
# 10491    7   1726     01-SEP-18         2019           30             7
# 457      7   1508     01-SEP-18         2019           30             7
# 8460     7   1709     14-JAN-17         2017           50            12
# 7530     7   1699     16-SEP-17         2018           33             8
# 2526     7   1597     27-OCT-18         2019           38             9
# 9550     7   1718     27-MAY-17         2018           17             4
# 21338    7   2045     15-SEP-18         2019           32             8
# 2525     7   1597     13-OCT-18         2019           36             9
# 12971    7   1824     04-JUN-16         2017           18             5
# 25433    7   2075     20-FEB-16         2017            3             1
# 24815    7   2071     07-OCT-17         2018           36             9
# ...

# %%
store_df.nlargest(20,'STRAK_COMP_TRAFFIC_DELTA')
# Out:
#        DIV  STORE WEEK_END_DATE  FISCAL_YEAR  FISCAL_WEEK  FISCAL_MONTH  \
# 26686    7   2084     23-JUL-16         2017           25             6
# 10491    7   1726     01-SEP-18         2019           30             7
# 457      7   1508     01-SEP-18         2019           30             7
# 8460     7   1709     14-JAN-17         2017           50            12
# 2526     7   1597     27-OCT-18         2019           38             9
# 7530     7   1699     16-SEP-17         2018           33             8
# 9550     7   1718     27-MAY-17         2018           17             4
# 21338    7   2045     15-SEP-18         2019           32             8
# 2525     7   1597     13-OCT-18         2019           36             9
# 12971    7   1824     04-JUN-16         2017           18             5
# 25433    7   2075     20-FEB-16         2017            3             1
# 12544    7   1819     20-FEB-16         2017            3             1
# ...

# %%
Max_earn_store=store_df[store_df['STORE']==2084]
Max_earn_store
# Out:
#        DIV  STORE WEEK_END_DATE  FISCAL_YEAR  FISCAL_WEEK  FISCAL_MONTH  \
# 26686    7   2084     23-JUL-16         2017           25             6
# 26770    7   2084     31-MAR-18         2019            8             2
# 26733    7   2084     15-JUL-17         2018           24             6
# 26729    7   2084     17-JUN-17         2018           20             5
# 26726    7   2084     27-MAY-17         2018           17             4
# ...    ...    ...           ...          ...          ...           ...
# 26822    7   2084     27-APR-19         2020           12             3
# 26831    7   2084     29-JUN-19         2020           21             5
# 26834    7   2084     20-JUL-19         2020           24             6
# 26689    7   2084     13-AUG-16         2017           28             7
# 26688    7   2084     06-AUG-16         2017           27             7
#
#        SALES_AMT_TY  SALES_AMT_LY    COMP_PCT  FISCAL_YEAR_LY  FISCAL_WEEK_LY  \
# ...

# %%
Max_earn_store.groupby('FISCAL_MONTH')['COMP_PCT'].max()
# Out:
# FISCAL_MONTH
# 1       0.531874
# 2       1.308296
# 3       0.660216
# 4       0.672953
# 5       0.797698
# 6     245.175193
# 7       0.572772
# 8       0.405439
# 9       0.641901
# 10      0.429311
# 11      0.608728
# 12      0.614836
# Name: COMP_PCT, dtype: float64

# %%
min_earn_store=store_df[store_df['STORE']==1505]
min_earn_store
# Out:
#      DIV  STORE WEEK_END_DATE  FISCAL_YEAR  FISCAL_WEEK  FISCAL_MONTH  \
# 168    7   1505     19-MAR-16         2017            7             2
# 274    7   1505     21-APR-18         2019           11             3
# 269    7   1505     17-MAR-18         2019            6             2
# 179    7   1505     04-JUN-16         2017           18             5
# 187    7   1505     30-JUL-16         2017           26             6
# ..   ...    ...           ...          ...          ...           ...
# 323    7   1505     27-APR-19         2020           12             3
# 229    7   1505     03-JUN-17         2018           18             5
# 223    7   1505     22-APR-17         2018           12             3
# 319    7   1505     30-MAR-19         2020            8             2
# 218    7   1505     18-MAR-17         2018            7             2
#
#      SALES_AMT_TY  SALES_AMT_LY  COMP_PCT  FISCAL_YEAR_LY  FISCAL_WEEK_LY  \
# ...

# %%
store_df.groupby('STORE')['COMP_PCT'].min()
# Out:
# STORE
# 1504   -0.498283
# 1505   -0.463546
# 1508   -0.392756
# 1514   -0.440151
# 1521   -0.441287
#           ...
# 2084   -0.491196
# 2085   -0.596114
# 2087   -0.324754
# 2088   -0.539537
# 2089   -0.428177
# Name: COMP_PCT, Length: 174, dtype: float64

# %%
min_earn_store.groupby('FISCAL_MONTH')['COMP_PCT'].max()
# Out:
# FISCAL_MONTH
# 1     0.130468
# 2     0.672325
# 3     0.657523
# 4     0.340341
# 5     0.396050
# 6     0.388414
# 7     0.119419
# 8     0.174508
# 9     0.347951
# 10    0.336604
# 11    0.309470
# 12    0.242842
# Name: COMP_PCT, dtype: float64

# %%
store_

# %%
store_df.nsmallest(20,'STRAK_COMP_TRAFFIC_DELTA')
# Out:
#        DIV  STORE WEEK_END_DATE  FISCAL_YEAR  FISCAL_WEEK  FISCAL_MONTH  \
# 21935    7   2050     02-FEB-19         2019           52            12
# 13512    7   1832     08-OCT-16         2017           36             9
# 21799    7   2050     30-APR-16         2017           13             3
# 1447     7   1549     10-FEB-18         2019            1             1
# 26475    7   2082     13-JAN-18         2018           50            12
# 21844    7   2050     25-MAR-17         2018            8             2
# 21933    7   2050     19-JAN-19         2019           50            12
# 21845    7   2050     01-APR-17         2018            9             3
# 21893    7   2050     03-MAR-18         2019            4             1
# 21897    7   2050     14-APR-18         2019           10             3
# 12247    7   1817     18-MAR-17         2018            7             2
# 13020    7   1824     03-JUN-17         2018           18             5
# ...

# %%
store_df.tail()
# Out:
#        DIV  STORE WEEK_END_DATE  FISCAL_YEAR  FISCAL_WEEK  FISCAL_MONTH  \
# 27188    7   2089     06-JUL-19         2020           22             6
# 27189    7   2089     13-JUL-19         2020           23             6
# 27190    7   2089     20-JUL-19         2020           24             6
# 27191    7   2089     27-JUL-19         2020           25             6
# 27192    7   2089     03-AUG-19         2020           26             6
#
#        SALES_AMT_TY  SALES_AMT_LY  COMP_PCT  FISCAL_YEAR_LY  FISCAL_WEEK_LY  \
# 27188      14397.25      15654.98 -0.080341            2019              22
# 27189      11424.20      11137.42  0.025749            2019              23
# 27190      10366.48      12987.83 -0.201831            2019              24
# 27191      12977.11      15016.29 -0.135798            2019              25
# 27192      11824.40      13970.76 -0.153632            2019              26
#
# ...

# %%
med_earn_store = store_df[store_df['STORE']==1508]
med_earn_store
# Out:
#      DIV  STORE WEEK_END_DATE  FISCAL_YEAR  FISCAL_WEEK  FISCAL_MONTH  \
# 457    7   1508     01-SEP-18         2019           30             7
# 456    7   1508     25-AUG-18         2019           29             7
# 453    7   1508     04-AUG-18         2019           26             6
# 458    7   1508     08-SEP-18         2019           31             8
# 454    7   1508     11-AUG-18         2019           27             7
# ..   ...    ...           ...          ...          ...           ...
# 378    7   1508     19-NOV-16         2017           42            10
# 484    7   1508     16-MAR-19         2020            6             2
# 405    7   1508     17-JUN-17         2018           20             5
# 490    7   1508     27-APR-19         2020           12             3
# 486    7   1508     30-MAR-19         2020            8             2
#
#      SALES_AMT_TY  SALES_AMT_LY  COMP_PCT  FISCAL_YEAR_LY  FISCAL_WEEK_LY  \
# ...

# %%
med_earn_store.groupby('FISCAL_MONTH')['COMP_PCT'].sum()
# Out:
# FISCAL_MONTH
# 1     -0.830809
# 2     -0.339878
# 3     -1.340209
# 4     -0.809317
# 5     -0.157114
# 6      4.665887
# 7     12.474657
# 8      1.334787
# 9     -0.154387
# 10    -0.705637
# 11    -0.868597
# 12    -0.711901
# Name: COMP_PCT, dtype: float64

# %%
st3=store_df[store_df['STORE']==2045]
st3
# Out:
#        DIV  STORE WEEK_END_DATE  FISCAL_YEAR  FISCAL_WEEK  FISCAL_MONTH  \
# 21338    7   2045     15-SEP-18         2019           32             8
# 21280    7   2045     22-JUL-17         2018           25             6
# 21337    7   2045     08-SEP-18         2019           31             8
# 21302    7   2045     06-JAN-18         2018           49            12
# 21286    7   2045     02-SEP-17         2018           31             8
# ...    ...    ...           ...          ...          ...           ...
# 21345    7   2045     10-NOV-18         2019           40            10
# 21363    7   2045     30-MAR-19         2020            8             2
# 21355    7   2045     19-JAN-19         2019           50            12
# 21379    7   2045     20-JUL-19         2020           24             6
# 21287    7   2045     23-SEP-17         2018           34             8
#
#        SALES_AMT_TY  SALES_AMT_LY  COMP_PCT  FISCAL_YEAR_LY  FISCAL_WEEK_LY  \
# ...

# %%
st3.groupby('FISCAL_MONTH')['COMP_PCT'].sum()
# Out:
# FISCAL_MONTH
# 1     0.353797
# 2     0.242286
# 3     0.295664
# 4     0.344061
# 5     0.824914
# 6     2.673192
# 7     1.943715
# 8     6.231520
# 9     0.071679
# 10    0.233351
# 11    0.297211
# 12    0.670730
# Name: COMP_PCT, dtype: float64

# %%
groupby = store_df.groupby(['STORE']).sum()
groupby
# Out:
#         DIV  FISCAL_YEAR  FISCAL_WEEK  FISCAL_MONTH  SALES_AMT_TY  \
# STORE
# 1504   1134       326942         4198          1043    2664072.03
# 1505   1225       353196         4321          1077    5455440.85
# 1508   1176       339075         4167          1038    6480104.37
# 1514   1260       363291         4494          1119    1552958.94
# 1521   1106       318858         4060          1009    2957393.69
# ...     ...          ...          ...           ...           ...
# 2084   1057       304790         4029           998    2572896.54
# 2085    973       280589         3649           905    2488178.53
# 2087    266        76747          933           233     381152.66
# 2088    644       185759         2380           590    1411734.09
# 2089    609       175666         2204           547    1527924.52
#
#        SALES_AMT_LY    COMP_PCT  FISCAL_YEAR_LY  FISCAL_WEEK_LY  \
# STORE
# 1504     2842719.17   -6.772227          326781            4194
# ...

# %%
storegp = store_df.groupby('STORE')['COMP_PCT'].sum()
storegp
# Out:
# STORE
# 1504     -6.772227
# 1505     -3.855631
# 1508     12.557482
# 1514     13.008601
# 1521      7.992444
#            ...
# 2084    262.338639
# 2085     21.343222
# 2087     -0.758418
# 2088      0.950471
# 2089     12.599983
# Name: COMP_PCT, Length: 174, dtype: float64

# %%
storegp.groupby('STORE').sum()
# Out:
#        SALES_AMT_TY
# STORE
# 1504     2664072.03
# 1505     5455440.85
# 1508     6480104.37
# 1514     1552958.94
# 1521     2957393.69
# 1533     3564483.07
# 1539     4013725.19
# 1545     3217549.51
# 1547     4219872.38
# 1549     1997789.22
# 1555     2419750.74
# 1559     2678888.43
# 1565     3151544.08
# 1574     2572635.46
# 1578     3324694.53
# 1597     4467744.17
# 1598     4181224.19
# 1600     1696449.99
# 1603      244234.17
# 1614       81673.69
# 1627     3111092.74
# 1628     2272044.81
# 1637     2085516.22
# 1642     3386529.35
# 1643      792634.08
# 1646     1218634.96
# 1649     3061986.96
# 1650     2398247.56
# 1652     2421315.91
# 1653     3179951.09
# ...             ...
# 2058     6248387.26
# 2059     2337393.09
# 2060     1740740.88
# 2061     2653176.25
# 2062     1618331.02
# 2063     4073749.28
# 2064     3021222.63
# 2065      184071.16
# 2066     2638837.23
# 2067     2364340.15
# 2068     2375492.94
# 2069     1752434.05
# 2070     1305515.46
# ...

# %%
store_df.shape
# Out:
# (27193, 104)

# %%
store_df.columns
# Out:
# Index(['DIV', 'STORE', 'WEEK_END_DATE', 'FISCAL_YEAR', 'FISCAL_WEEK',
#        'FISCAL_MONTH', 'SALES_AMT_TY', 'SALES_AMT_LY', 'COMP_PCT',
#        'FISCAL_YEAR_LY',
#        ...
#        'AVG_AM_TENURE_DAYS', 'FT_COUNT', 'FT_TENURE_DAYS',
#        'AVG_FT_TENURE_DAYS', 'PT_COUNT', 'PT_TENURE_DAYS',
#        'AVG_PT_TENURE_DAYS', 'NUM_OF_EMPS', 'TOT_TENURE_DAYS',
#        'TOT_AVG_TENURE_DAYS'],
#       dtype='object', length=104)

# %%
store_df.STORE.value_counts()
# Out:
# 2061    180
# 1687    180
# 1808    180
# 2067    180
# 1705    180
# 1817    180
# 1816    180
# 2077    180
# 2041    180
# 1514    180
# 2010    180
# 1565    179
# 1801    179
# 1825    179
# 1837    179
# 1819    179
# 2013    179
# 2009    179
# 2057    179
# 2063    179
# 1598    179
# 2068    179
# 1650    179
# 1854    179
# 1559    179
# 2079    179
# 1637    179
# 1834    178
# 1723    178
# 1691    178
#        ...
# 1711    138
# 1717    137
# 2083    137
# 1539    128
# 1701    128
# 1547    125
# 2049    124
# 1844    121
# 1549    112
# 1843    112
# 1718    108
# 2048    108
# 2082    101
# 1699     96
# 2088     92
# 1643     88
# 2089     87
# 1820     82
# 1845     81
# 1729     72
# 1683     60
# 1847     51
# 1846     45
# 1848     43
# 2087     38
# 1849     36
# 2065     16
# 1603     15
# 1730     10
# 1614      6
# Name: STORE, Length: 174, dtype: int64

# %%
store_df.DIV.value_counts()
# Out:
# 7    27193
# Name: DIV, dtype: int64

# %%
store_df[]

# %%
st4 = store_df[store_df['STORE']==1521]
st4
# Out:
#      DIV  STORE WEEK_END_DATE  FISCAL_YEAR  FISCAL_WEEK  FISCAL_MONTH  \
# 814    7   1521     08-SEP-18         2019           31             8
# 773    7   1521     11-NOV-17         2018           41            10
# 762    7   1521     12-AUG-17         2018           28             7
# 692    7   1521     26-MAR-16         2017            8             2
# 815    7   1521     15-SEP-18         2019           32             8
# ..   ...    ...           ...          ...          ...           ...
# 767    7   1521     30-SEP-17         2018           35             9
# 783    7   1521     27-JAN-18         2018           52            12
# 758    7   1521     15-JUL-17         2018           24             6
# 760    7   1521     29-JUL-17         2018           26             6
# 712    7   1521     13-AUG-16         2017           28             7
#
#      SALES_AMT_TY  SALES_AMT_LY  COMP_PCT  FISCAL_YEAR_LY  FISCAL_WEEK_LY  \
# ...

# %%
st4.groupby('FISCAL_MONTH')['COMP_PCT'].sum()
# Out:
# FISCAL_MONTH
# 1     0.645010
# 2     0.566397
# 3     0.288373
# 4     0.843833
# 5     0.980302
# 6     0.652304
# 7     0.391408
# 8     2.538561
# 9    -0.232107
# 10    0.945576
# 11   -0.308459
# 12    0.681246
# Name: COMP_PCT, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(18,8))
ax.hist(store_df['COMP_PCT'], color='#8CB4E1', alpha=1.0, bins=50, range = [-0.2,2],
       label='Comperative sale')
ax.hist(store_df['STRAK_COMP_TRAFFIC_DELTA'], color='#007D00', alpha=0.7, bins=50, range = [-0.2, 2],
       label='Strak Comp Delta')
plt.xlabel('Distribution', fontsize=12)
plt.ylabel('frequency', fontsize=12)
plt.title('Corelation', fontsize=15)
plt.tick_params(labelsize=12)
plt.legend()
plt.show()

# %%
Year2017 = store_df[store_df['FISCAL_YEAR'] == 2017]
Year2017
# Out:
#        DIV  STORE WEEK_END_DATE  FISCAL_YEAR  FISCAL_WEEK  FISCAL_MONTH  \
# 26686    7   2084     23-JUL-16         2017           25             6
# 8460     7   1709     14-JAN-17         2017           50            12
# 12971    7   1824     04-JUN-16         2017           18             5
# 25433    7   2075     20-FEB-16         2017            3             1
# 12544    7   1819     20-FEB-16         2017            3             1
# ...    ...    ...           ...          ...          ...           ...
# 17964    7   2016     14-JAN-17         2017           50            12
# 3644     7   1643     20-AUG-16         2017           29             7
# 5591     7   1672     02-JUL-16         2017           22             6
# 19337    7   2027     15-OCT-16         2017           37             9
# 13512    7   1832     08-OCT-16         2017           36             9
#
#        SALES_AMT_TY  SALES_AMT_LY    COMP_PCT  FISCAL_YEAR_LY  FISCAL_WEEK_LY  \
# ...

# %%
year2017_accessory = store_df[['STORE','FISCAL_YEAR','FISCAL_MONTH','COMP_PCT','ACCESSORY_UNITS','ACCESSORY_VALUE','ACCESSORY_HOSIERY_UNITS','ACCESSORY_HOSIERY_VALUE','ACCESSORY_COATS_UNITS','ACCESSORY_COATS_VALUE','ACCESSORY_SHIRT_SWEATER_UNITS','ACCESSORY_SHIRT_SWEATER_VALUE','ACCESSORY_PLGS_LUGGAGE_UNITS','ACCESSORY_PLGS_LUGGAGE_VALUE','ACCESSORY_BELTS_UNITS','ACCESSORY_BELTS_VALUE','ACCESSORY_SHOE_CARE_UNITS']]

# %%
year2017_accessory = year2017_accessory[year2017_accessory['FISCAL_YEAR']== 2017]

# %%
year2017_accessory.corr()
# Out:
#                                   STORE  FISCAL_YEAR  FISCAL_MONTH  COMP_PCT  \
# STORE                          1.000000          NaN      0.006157  0.014876
# FISCAL_YEAR                         NaN          NaN           NaN       NaN
# FISCAL_MONTH                   0.006157          NaN      1.000000 -0.013928
# COMP_PCT                       0.014876          NaN     -0.013928  1.000000
# ACCESSORY_UNITS               -0.018499          NaN      0.070282  0.004415
# ACCESSORY_VALUE               -0.228466          NaN      0.105446  0.001406
# ACCESSORY_HOSIERY_UNITS       -0.008158          NaN      0.020284  0.000898
# ACCESSORY_HOSIERY_VALUE       -0.275288          NaN      0.049842 -0.000358
# ACCESSORY_COATS_UNITS         -0.005826          NaN      0.338329 -0.000207
# ACCESSORY_COATS_VALUE         -0.182089          NaN      0.266763 -0.002600
# ACCESSORY_SHIRT_SWEATER_UNITS  0.133633          NaN      0.034301  0.005595
# ...

# %%
year2017_accessory
# Out:
#        STORE  FISCAL_YEAR  FISCAL_MONTH    COMP_PCT  ACCESSORY_UNITS  \
# 26686   2084         2017             6  245.175193              133
# 8460    1709         2017            12    6.630358              162
# 12971   1824         2017             5    3.540078               94
# 25433   2075         2017             1    3.342601              153
# 12544   1819         2017             1    3.284209              334
# ...      ...          ...           ...         ...              ...
# 17964   2016         2017            12   -0.659783               24
# 3644    1643         2017             7   -0.680211               26
# 5591    1672         2017             6   -0.685593               80
# 19337   2027         2017             9   -0.700524               49
# 13512   1832         2017             9   -0.778297               46
#
#        ACCESSORY_VALUE  ACCESSORY_HOSIERY_UNITS  ACCESSORY_HOSIERY_VALUE  \
# ...

# %%
fig, ax = plt.subplots(figsize=(6, 6))

corr = year2017_accessory.corr()
# create a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, cmap=cmap, mask = mask, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5});

# %%
st_acc1=Year2017.groupby('STORE')['ACCESSORY_VALUE'].sum()
st_acc1.head(20).plot(kind='bar')

# %%
st_shoes=Year2017.groupby('STORE')['SHOES_VALUE'].sum()
st_shoes.head(20).plot(kind='bar')

# %%
##accessory=store_df[['STORE','FISCAL_YEAR','FISCAL_MONTH','ACCESSORY_UNITS','ACCESSORY_COATS_UNITS','ACCESSORY_SHIRT_SWEATER_UNITS','ACCESSORY_PLGS_LUGGAGE_UNITS','ACCESSORY_BELTS_UNITS','ACCESSORY_SHOE_CARE_UNITS']]

# %%
##accessory.head(5)
# Out:
#        STORE  FISCAL_YEAR  FISCAL_MONTH  ACCESSORY_UNITS  \
# 26686   2084         2017             6              133
# 10491   1726         2019             7              255
# 457     1508         2019             7              281
# 8460    1709         2017            12              162
# 7530    1699         2018             8              163
#
#        ACCESSORY_COATS_UNITS  ACCESSORY_SHIRT_SWEATER_UNITS  \
# 26686                      3                             50
# 10491                      3                             75
# 457                        9                             48
# 8460                      18                             31
# 7530                       9                             49
#
#        ACCESSORY_PLGS_LUGGAGE_UNITS  ACCESSORY_BELTS_UNITS  \
# 26686                             1                      7
# 10491                             1                     20
# 457                               1                     44
# ...

# %%
Year2017.groupby('FISCAL_MONTH')['COMP_PCT'].sum().plot(kind='bar')

# %%
Year2018 = store_df[store_df['FISCAL_YEAR'] == 2018]
Year2018
# Out:
#        DIV  STORE WEEK_END_DATE  FISCAL_YEAR  FISCAL_WEEK  FISCAL_MONTH  \
# 7530     7   1699     16-SEP-17         2018           33             8
# 9550     7   1718     27-MAY-17         2018           17             4
# 24815    7   2071     07-OCT-17         2018           36             9
# 27106    7   2089     18-NOV-17         2018           42            10
# 13558    7   1832     07-OCT-17         2018           36             9
# ...    ...    ...           ...          ...          ...           ...
# 12247    7   1817     18-MAR-17         2018            7             2
# 14844    7   1842     25-MAR-17         2018            8             2
# 13020    7   1824     03-JUN-17         2018           18             5
# 24636    7   2070     25-MAR-17         2018            8             2
# 26475    7   2082     13-JAN-18         2018           50            12
#
#        SALES_AMT_TY  SALES_AMT_LY  COMP_PCT  FISCAL_YEAR_LY  FISCAL_WEEK_LY  \
# ...

# %%
Year2019 = store_df[store_df['FISCAL_YEAR'] == 2019]
Year2019
# Out:
#        DIV  STORE WEEK_END_DATE  FISCAL_YEAR  FISCAL_WEEK  FISCAL_MONTH  \
# 10491    7   1726     01-SEP-18         2019           30             7
# 457      7   1508     01-SEP-18         2019           30             7
# 2526     7   1597     27-OCT-18         2019           38             9
# 21338    7   2045     15-SEP-18         2019           32             8
# 2525     7   1597     13-OCT-18         2019           36             9
# ...    ...    ...           ...          ...          ...           ...
# 11122    7   1803     26-JAN-19         2019           51            12
# 19970    7   2034     02-FEB-19         2019           52            12
# 1447     7   1549     10-FEB-18         2019            1             1
# 15172    7   1844     12-JAN-19         2019           49            12
# 19953    7   2034     22-SEP-18         2019           33             8
#
#        SALES_AMT_TY  SALES_AMT_LY   COMP_PCT  FISCAL_YEAR_LY  FISCAL_WEEK_LY  \
# ...

# %%
Year2018.groupby('FISCAL_MONTH')['COMP_PCT'].sum().plot(kind='bar')

# %%
Year2019.groupby('FISCAL_MONTH')['COMP_PCT'].sum().plot(kind='bar')
