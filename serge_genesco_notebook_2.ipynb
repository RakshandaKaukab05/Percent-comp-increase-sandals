# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pprint as pp
import IPython
from IPython.display import display, HTML
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"
CSS = """
.output {
    flex-direction: row;
}
"""
HTML('<style>{}</style>'.format(CSS))
pd.set_option('display.max_columns', None)

# %% [markdown]
# ---
#
# ## Mapping categories to DF1 and removing outliers below

# %%
df1 = pd.read_csv('./data/0826export_column_filter_1.csv')
df1.columns = df1.columns.str.lower()

df2 = pd.read_excel('./documentation/store_master.xlsx')
df2.columns = df2.columns.str.lower()

categories_to_map = ['class', 
                     'store_city', 
                     'store_state', 
                     'close_date', 
                     'gross_feet'] # must be df2's LOWERED column names

def map_my_dataframe(df1, df2, a_list):
    """Returns DataFrame(df1)
    maps str items in a_list, from df2 onto df1.
    the joint variable for mapping is the store number.
    
    # !! df1 and df2 column names must be lower-case !!
    """
    joint_var = 'store'
    for category in a_list:
        
        df_2_dict = dict(zip(df2[joint_var], df2[category]))
        
        df1[category] = df1[joint_var].map(df_2_dict)
        
    return df1
    
df = map_my_dataframe(df1, df2, categories_to_map)
df = df[df.store != 2084]

closed = df[df.close_date.notna()]

# %% [markdown]
# ---
#
# ### Remove outlier store(2084), make DF for closed stores.

# %% [markdown]
# ---
#
# ## Making dataframes to concat and compare below by `store`:
#
# Grouping DataFrames's by `'store'`, `'mean()'` of:
#  - `df1`: full original data frame
#  - `top_avg`: top by `comp_pct`
#  - `bot_avg`: bottom by `comp_pct`
#  - `closed_avg`: by closed store

# %%
# all_avg = df.groupby(['store','fiscal_year','fiscal_month']).mean().median().round(3)
# top_avg = df.groupby(['store','fiscal_year','fiscal_month']).mean().nlargest(27, 'comp_pct').median().round(3)
# bot_avg = df.groupby(['store','fiscal_year','fiscal_month']).mean().nsmallest(27, 'comp_pct').median().round(3)
# closed_avg = closed.groupby(['store','fiscal_year','fiscal_month']).mean().median().round(3)

# # Concatenating
# for_compare = pd.concat([
#     all_avg.rename('all_means').to_frame(),
#     top_avg.rename('top_means').to_frame(),
#     bot_avg.rename('bot_means').to_frame(),
#     closed_avg.rename('closed_means').to_frame()
# ], axis=1).iloc[1:, :]

# for_compare

all_avg_by_store = df.groupby(['store']).mean().mean().round(4)
top_avg_by_store = df.groupby(['store']).mean().nlargest(20, 'comp_pct').mean().round(4)
bot_avg_by_store = df.groupby(['store']).mean().nsmallest(20, 'comp_pct').mean().round(4)
closed_avg_by_store = closed.groupby(['store']).mean().mean().round(4)

# Concatenating
for_compare_by_store = pd.concat([
#     all_avg_by_store.rename('all_means').to_frame(),
    top_avg_by_store.rename('top_store_avgs').to_frame(),
    bot_avg_by_store.rename('bot_store_avgs').to_frame(),
    closed_avg_by_store.rename('closed_store_avgs').to_frame()
], axis=1).iloc[3:, :]

for_compare_by_store
# Out:
#                               top_store_avgs  bot_store_avgs  \
# comp_pct                              0.1587         -0.0535
# mark_down_amt_ty                   2124.6918       1711.4393
# payroll_adj_hours                   143.3224        129.9134
# strak_traffic                      1084.4834        905.5472
# strak_sales_amt                   20370.3780      16344.4602
# special_order_amt                  3087.8884       2167.4445
# sales_value                       20368.6170      16340.8817
# shoes_units                          94.8406         80.0852
# shoes_value                       12554.7852      10419.3385
# multi_value                        5018.2321       4499.7414
# payroll_units                       147.0773        138.5657
# payroll_value                      2751.9598       2502.1189
# accessory_value                    7812.1922       5921.5432
# trans_cnt_returns                     7.7938          5.8468
# ty_mark_down_pct                      0.1069          0.1065
# strak_conversion_pct                  0.1341          0.1373
# strak_sls_per_shopper                19.9361         19.9814
# strak_avg_trans_size                147.0986        144.4604
# strak_shopper_to_assoc_ratio          7.4773          6.3493
# strak_comp_traffic_delta              0.0246         -0.1908
# shoe_multi_pct                        0.4063          0.4171
# special_order_pct_to_sls              0.1517          0.1314
# footwear_units_pct                    0.3121          0.3242
# nonfootwear_units_pct                 0.6875          0.6755
# avg_unit_price                        0.0157          0.0162
# avg_footwear_price                  136.0123        133.4316
# avg_nonfootwewar_price               35.1251         32.3528
# footwear_amt_pct                      0.6321          0.6570
# nonfootwear_amt_pct                   0.3678          0.3430
# multi_amt_pct                         0.3912          0.4011
# payroll_pct                           0.1429          0.1632
# avg_pay_per_hr                       18.4724         17.3122
# sales_amt_per_pay_hour              137.3018        113.1264
# avg_mgr_tenure_days                1244.6367       1606.6196
# avg_am_tenure_days                  812.6148        983.0229
# avg_ft_tenure_days                  990.3433        299.5023
# avg_pt_tenure_days                  403.7584        290.0885
# tot_avg_tenure_days                 963.0595        818.3781
# gross_feet                         1936.9000       1771.4000
#
#                               closed_store_avgs
# comp_pct                                -0.0148
# mark_down_amt_ty                      1144.2139
# payroll_adj_hours                      106.2597
# strak_traffic                          779.3127
# strak_sales_amt                      15008.3269
# special_order_amt                     2039.8378
# sales_value                          15003.0004
# shoes_units                             65.7381
# shoes_value                           9758.1475
# multi_value                           3764.7171
# payroll_units                          122.3064
# payroll_value                         2150.6282
# accessory_value                       5244.8529
# trans_cnt_returns                        5.5502
# ty_mark_down_pct                         0.0842
# strak_conversion_pct                     0.1393
# strak_sls_per_shopper                   21.0058
# strak_avg_trans_size                   143.7884
# strak_shopper_to_assoc_ratio             6.6200
# strak_comp_traffic_delta                -0.1541
# shoe_multi_pct                           0.3559
# special_order_pct_to_sls                 0.1257
# footwear_units_pct                       0.2973
# nonfootwear_units_pct                    0.7026
# avg_unit_price                           0.0154
# avg_footwear_price                     145.6106
# avg_nonfootwewar_price                  33.5745
# footwear_amt_pct                         0.6343
# nonfootwear_amt_pct                      0.3657
# multi_amt_pct                            0.3488
# payroll_pct                              0.1563
# avg_pay_per_hr                          17.0556
# sales_amt_per_pay_hour                 117.6448
# avg_mgr_tenure_days                   2073.2510
# avg_am_tenure_days                     768.4298
# avg_ft_tenure_days                     659.5943
# avg_pt_tenure_days                     359.1322
# tot_avg_tenure_days                   1189.1187
# gross_feet                            1766.1111

# %% [markdown]
# ---
# ## Making dataframes to concat and compare below by `class`:
#
# ### Commented out classes do not have enough stores to do top and bot 10 store difference checks

# %%
classes = df['class'].unique()

mall_top = df[df['class'] == classes[0]].groupby(['store']).mean().nlargest(10, 'comp_pct').iloc[:, 3:].mean().rename('mall_top').to_frame()
mall_bot = df[df['class'] == classes[0]].groupby(['store']).mean().nsmallest(10, 'comp_pct').iloc[:, 3:].mean().rename('mall_bot').to_frame()

# open_air_top = df[df['class'] == classes[1]].groupby(['store']).mean().nlargest(10, 'comp_pct').iloc[:, 3:].mean().rename('open_air_top').to_frame()
# open_air_bot = df[df['class'] == classes[1]].groupby(['store']).mean().nsmallest(10, 'comp_pct').iloc[:, 3:].mean().rename('open_air_bot').to_frame()

# downtown_top = df[df['class'] == classes[2]].groupby(['store']).mean().nlargest(10, 'comp_pct').iloc[:, 3:].mean().rename('downtown_top').to_frame()
# downtown_bot = df[df['class'] == classes[2]].groupby(['store']).mean().nsmallest(10, 'comp_pct').iloc[:, 3:].mean().rename('downtown_bot').to_frame()

# street_top = df[df['class'] == classes[3]].groupby(['store']).mean().nlargest(10, 'comp_pct').iloc[:, 3:].mean().rename('street_top').to_frame()
# street_bot = df[df['class'] == classes[3]].groupby(['store']).mean().nsmallest(10, 'comp_pct').iloc[:, 3:].mean().rename('street_bot').to_frame()

airport_top = df[df['class'] == classes[4]].groupby(['store']).mean().nlargest(10, 'comp_pct').iloc[:, 3:].mean().rename('airport_top').to_frame()
airport_bot = df[df['class'] == classes[4]].groupby(['store']).mean().nsmallest(10, 'comp_pct').iloc[:, 3:].mean().rename('airport_bot').to_frame()

# lifestyle_top = df1[df1['class'] == classes[5]].groupby(['store']).mean().nlargest(10, 'comp_pct').iloc[:, 3:].mean().rename('lifestyle_top').to_frame()
# lifestyle_bot = df1[df1['class'] == classes[5]].groupby(['store']).mean().nsmallest(10, 'comp_pct').iloc[:, 3:].mean().rename('lifestyle_bot').to_frame()

outlet_top = df[df['class'] == classes[6]].groupby(['store']).mean().nlargest(10, 'comp_pct').iloc[:, 3:].mean().rename('outlet_top').to_frame()
outlet_bot = df[df['class'] == classes[6]].groupby(['store']).mean().nsmallest(10, 'comp_pct').iloc[:, 3:].mean().rename('outlet_bot').to_frame()

for_compare_by_class = pd.concat([mall_top, mall_bot, airport_top, airport_bot, outlet_top, outlet_bot], axis=1)
# for_compare_by_class

# %% [markdown]
# ---
#
# ## MALL STORES:
#  - #### Absolute percentage(%) differences between averages of top and bot mall stores' variables:

# %%
abs(abs(mall_bot.iloc[1:,0]-mall_top.iloc[1:,0]) / ((mall_bot.iloc[1:,0] + mall_top.iloc[1:,0]) * 0.5) * 100).to_frame('abs_%_diff')
# Out:
#                               abs_%_diff
# mark_down_amt_ty               25.493565
# payroll_adj_hours               1.693765
# strak_traffic                   7.404775
# strak_sales_amt                23.350967
# special_order_amt              35.176158
# sales_value                    23.348071
# shoes_units                    25.909604
# shoes_value                    27.212221
# multi_value                    33.870609
# payroll_units                   0.937128
# payroll_value                   7.840776
# accessory_value                16.330514
# trans_cnt_returns              26.260592
# ty_mark_down_pct                5.786198
# strak_conversion_pct           11.951084
# strak_sls_per_shopper          16.666606
# strak_avg_trans_size            4.348530
# strak_shopper_to_assoc_ratio    7.546524
# strak_comp_traffic_delta      255.203971
# shoe_multi_pct                 11.425645
# special_order_pct_to_sls       11.391806
# footwear_units_pct              3.883224
# nonfootwear_units_pct           1.812479
# avg_unit_price                  3.807681
# avg_footwear_price              0.946780
# avg_nonfootwewar_price          7.533131
# footwear_amt_pct                1.281383
# nonfootwear_amt_pct             2.537105
# multi_amt_pct                  11.281948
# payroll_pct                    13.615914
# avg_pay_per_hr                 10.761604
# sales_amt_per_pay_hour         23.782637
# avg_mgr_tenure_days            36.306432
# avg_am_tenure_days             55.178889
# avg_ft_tenure_days             40.538596
# avg_pt_tenure_days             46.603252
# tot_avg_tenure_days            10.671922
# gross_feet                      7.644654

# %% [markdown]
# ---
#
# ## AIRPORT STORES:
#  - #### Absolute percentage(%) differences between averages of top and bot airport stores' variables:

# %%
abs(abs(airport_bot.iloc[1:,0]-airport_top.iloc[1:,0]) / ((airport_bot.iloc[1:,0] + airport_top.iloc[1:,0]) * 0.5) * 100).to_frame('abs_%_diff')
# Out:
#                               abs_%_diff
# mark_down_amt_ty               33.349293
# payroll_adj_hours              18.660824
# strak_traffic                  30.956370
# strak_sales_amt                30.115526
# special_order_amt              19.930650
# sales_value                    30.088844
# shoes_units                    30.580276
# shoes_value                    28.356516
# multi_value                    32.473314
# payroll_units                  19.255683
# payroll_value                  24.373565
# accessory_value                31.384410
# trans_cnt_returns              56.637767
# ty_mark_down_pct                6.412140
# strak_conversion_pct            5.533689
# strak_sls_per_shopper           6.021613
# strak_avg_trans_size            0.250370
# strak_shopper_to_assoc_ratio   10.307315
# strak_comp_traffic_delta      400.170782
# shoe_multi_pct                  4.104888
# special_order_pct_to_sls        0.347771
# footwear_units_pct              3.969352
# nonfootwear_units_pct           0.989802
# avg_unit_price                  3.516257
# avg_footwear_price              2.372000
# avg_nonfootwewar_price          5.108229
# footwear_amt_pct                0.991046
# nonfootwear_amt_pct             0.725531
# multi_amt_pct                   4.227599
# payroll_pct                     7.395963
# avg_pay_per_hr                  6.538768
# sales_amt_per_pay_hour         12.327652
# avg_mgr_tenure_days            62.508963
# avg_am_tenure_days             64.814526
# avg_ft_tenure_days            118.674498
# avg_pt_tenure_days             25.937623
# tot_avg_tenure_days            46.210015
# gross_feet                     20.294280

# %% [markdown]
# ---
#
# ## OUTLET STORES:
#  - #### Absolute percentage(%) differences between averages of top and bot outlet stores' variables:

# %%
# outlet store differences
abs(abs(outlet_bot.iloc[1:,0]-outlet_top.iloc[1:,0]) / ((outlet_bot.iloc[1:,0] + outlet_top.iloc[1:,0]) * 0.5) * 100).to_frame('abs_%_diff')
# Out:
#                               abs_%_diff
# mark_down_amt_ty                2.549816
# payroll_adj_hours              13.399895
# strak_traffic                  12.273005
# strak_sales_amt                16.188806
# special_order_amt              10.274374
# sales_value                    16.211427
# shoes_units                    19.149166
# shoes_value                    20.087996
# multi_value                    11.542833
# payroll_units                   4.084939
# payroll_value                   5.536708
# accessory_value                 8.141200
# trans_cnt_returns              24.976449
# ty_mark_down_pct               12.566542
# strak_conversion_pct            5.377097
# strak_sls_per_shopper           5.498228
# strak_avg_trans_size            0.497400
# strak_shopper_to_assoc_ratio   15.427341
# strak_comp_traffic_delta      174.740099
# shoe_multi_pct                  5.691858
# special_order_pct_to_sls        6.960984
# footwear_units_pct              0.421821
# nonfootwear_units_pct           0.209528
# avg_unit_price                  0.409995
# avg_footwear_price              1.164664
# avg_nonfootwewar_price          4.630054
# footwear_amt_pct                1.904013
# nonfootwear_amt_pct             4.117117
# multi_amt_pct                   7.569279
# payroll_pct                    14.977790
# avg_pay_per_hr                  2.950171
# sales_amt_per_pay_hour         14.915703
# avg_mgr_tenure_days            86.448324
# avg_am_tenure_days              9.294980
# avg_ft_tenure_days              6.493645
# avg_pt_tenure_days             62.505554
# tot_avg_tenure_days            61.796806
# gross_feet                      4.517351

# %% [markdown]
# ---
#
# ## Making dataframes to concat and compare below by `fiscal_week`, top and bot `comp_pct`.
#
# Each observation within `df1` is `fiscal_week`, and total len is 27042. We will sample top and bot 1000 fiscal weeks by `comp_pct`, then compare the variable of these fiscal weeks with side by side.

# %%
fiscal_wk_top = df.set_index(['store', 'fiscal_week']).nlargest(1000, 'comp_pct').iloc[:,2:]
fiscal_wk_bot = df.set_index(['store', 'fiscal_week']).nsmallest(1000, 'comp_pct').iloc[:,2:]


for_compare_by_fiscal_week = pd.concat([fiscal_wk_top.mean().rename('top_comp_pct_weeks'), 
                                        fiscal_wk_bot.mean().rename('bot_comp_pct_weeks')], axis=1)
for_compare_by_fiscal_week
# Out:
#                               top_comp_pct_weeks  bot_comp_pct_weeks
# comp_pct                                0.956945           -0.436951
# mark_down_amt_ty                     2315.725860         1167.420960
# payroll_adj_hours                     130.121000          118.318000
# strak_traffic                         950.349000          704.071000
# strak_sales_amt                     19588.119570        10442.047940
# special_order_amt                    2834.251660         1497.460080
# sales_value                         19585.374860        10423.961340
# shoes_units                           102.545000           56.047000
# shoes_value                         12795.650900         6951.279400
# multi_value                          5961.896140         2716.021310
# payroll_units                         132.810200          120.839070
# payroll_value                        2527.680660         1865.134330
# accessory_value                      6788.309530         3472.667940
# trans_cnt_returns                       6.599000            5.793000
# ty_mark_down_pct                        0.123241            0.115113
# strak_conversion_pct                    0.149323            0.132648
# strak_sls_per_shopper                  22.849781           16.942274
# strak_avg_trans_size                  152.159863          125.963740
# strak_shopper_to_assoc_ratio            7.012810            5.786176
# strak_comp_traffic_delta                0.807622           -0.569600
# shoe_multi_pct                          0.476657            0.396079
# special_order_pct_to_sls                0.146222            0.146832
# footwear_units_pct                      0.333794            0.326425
# nonfootwear_units_pct                   0.665672            0.673189
# avg_unit_price                          0.016328            0.017266
# avg_footwear_price                    129.293081          127.121806
# avg_nonfootwewar_price                 32.145060           28.813736
# footwear_amt_pct                        0.662582            0.673652
# nonfootwear_amt_pct                     0.337350            0.326347
# multi_amt_pct                           0.457265            0.377480
# payroll_pct                             0.138388            0.202998
# avg_pay_per_hr                         18.808074           15.379458
# sales_amt_per_pay_hour                144.113440           83.409613
# avg_mgr_tenure_days                  2203.562000         1974.181500
# avg_am_tenure_days                    958.407010         1036.887000
# avg_ft_tenure_days                    491.897500          453.566920
# avg_pt_tenure_days                    510.596870          479.074170
# tot_avg_tenure_days                  1185.712000         1206.908000
# gross_feet                           1920.399000         1892.422000

# %% [markdown]
# ---
#
# ## FISCAL WEEKS:
#  - #### Absolute percentage(%) differences between averages of top and bot fiscal weeks' variables:

# %%
wk_top = fiscal_wk_top.mean().rename('top_comp_pct_weeks')
wk_bot = fiscal_wk_bot.mean().rename('bot_comp_pct_weeks')

abs(abs(wk_top-wk_bot) / ((wk_top+wk_bot) * 0.5) * 100).to_frame('abs_%_diff')
# Out:
#                                abs_%_diff
# comp_pct                       536.120464
# mark_down_amt_ty                65.934912
# payroll_adj_hours                9.501729
# strak_traffic                   29.772126
# strak_sales_amt                 60.912558
# special_order_amt               61.721170
# sales_value                     61.057089
# shoes_units                     58.638519
# shoes_value                     59.192709
# multi_value                     74.807691
# payroll_units                    9.439120
# payroll_value                   30.165000
# accessory_value                 64.626233
# trans_cnt_returns               13.008393
# ty_mark_down_pct                 6.819745
# strak_conversion_pct            11.827448
# strak_sls_per_shopper           29.691892
# strak_avg_trans_size            18.837757
# strak_shopper_to_assoc_ratio    19.167664
# strak_comp_traffic_delta      1157.220363
# shoe_multi_pct                  18.465743
# special_order_pct_to_sls         0.415903
# footwear_units_pct               2.232155
# nonfootwear_units_pct            1.122858
# avg_unit_price                   5.585948
# avg_footwear_price               1.693564
# avg_nonfootwewar_price          10.929756
# footwear_amt_pct                 1.656880
# nonfootwear_amt_pct              3.315809
# multi_amt_pct                   19.115901
# payroll_pct                     37.851358
# avg_pay_per_hr                  20.057702
# sales_amt_per_pay_hour          53.360594
# avg_mgr_tenure_days             10.981071
# avg_am_tenure_days               7.866509
# avg_ft_tenure_days               8.108307
# avg_pt_tenure_days               6.370339
# tot_avg_tenure_days              1.771782
# gross_feet                       1.467522
