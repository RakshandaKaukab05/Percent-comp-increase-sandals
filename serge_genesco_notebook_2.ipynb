# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pprint as pp
# import IPython
# from IPython.display import display, HTML
# from IPython.core.interactiveshell import InteractiveShell

# InteractiveShell.ast_node_interactivity = "all"
# CSS = """
# .output {
#     flex-direction: row;
# }
# """
# HTML('<style>{}</style>'.format(CSS))
pd.set_option('display.max_columns', None)

# %% [markdown]
# ---
#
# ## Mapping categories to DF1 below

# %%
df1 = pd.read_csv('./data/0826export_column_filter_1.csv')
df1.columns = df1.columns.str.lower()

df2 = pd.read_excel('./documentation/store_master.xlsx')
df2.columns = df2.columns.str.lower()

# column creation and mapping
#############################
# store class column
df2_store_dict = dict(zip(df2['store'], df2['class']))
df1['class'] = df1['store'].map(df2_store_dict)

# store city column 
df2_city_dict = dict(zip(df2['store'], df2['store_city']))
df1['city'] = df1['store'].map(df2_city_dict)

# store state column
df2_state_dict = dict(zip(df2['store'], df2['store_state']))
df1['state'] = df1['store'].map(df2_state_dict)

# store close date
df2_closed_dict = dict(zip(df2['store'], df2['close_date']))
df1['close_date'] = df1['store'].map(df2_closed_dict)

df2_ft_dict = dict(zip(df2['store'], df2['gross_feet']))
df1['gross_feet'] = df1['store'].map(df2_ft_dict)

# %% [markdown]
# ---
#
# ## Below remove outlier store

# %%
df1 = df1[df1.store != 2084]

# %%
pd.pivot_table(closed, index=['store'],columns='fiscal_year',values='comp_pct')
# Out:
# fiscal_year      2017      2018      2019      2020
# store
# 1643        -0.181329 -0.123526       NaN       NaN
# 1652         0.259425 -0.037050  0.153779 -0.055691
# 1670         0.460118 -0.381940 -0.070992       NaN
# 1711        -0.042366 -0.033682  0.101881  0.099241
# 1717        -0.040280 -0.056802 -0.036926 -0.406107
# 1803        -0.090754 -0.046967 -0.063759 -0.142300
# 1820         0.096273  0.005422       NaN       NaN
# 1832        -0.106470  0.088853  0.154067       NaN
# 2065        -0.076738       NaN       NaN       NaN

# %% [markdown]
# ---
#
# ## Making dataframes to concat and compare below:
#
# Grouping DataFrames's by `'store','fiscal_year','fiscal_month','fiscal_week'`, `'mean()'` of:
#  - `df1` fir compare
#  - `top_avg`: top 27 by `comp_pct`
#  - `bot_avg`: bottom 27 by `comp_pct`
#  - `closed_avg`: by closed store

# %%
closed = df1[df1.close_date.notna()]


all_avg = df1.groupby(['store','fiscal_year','fiscal_month','fiscal_week']).mean().mean()
top_avg = df1.groupby(['store','fiscal_year','fiscal_month','fiscal_week']).mean().nlargest(27, 'comp_pct').mean()
bot_avg = df1.groupby(['store','fiscal_year','fiscal_month','fiscal_week']).mean().nsmallest(27, 'comp_pct').mean()
closed_avg = closed.groupby(['store','fiscal_year','fiscal_month','fiscal_week']).mean().mean()

# Concatenating
for_compare = pd.concat([
    all_avg.rename('all_averages').to_frame(),
                         top_avg.rename('top_averages').to_frame(),
                         bot_avg.rename('bot_averages').to_frame(),
                         closed_avg.rename('closed_averages').to_frame()
], axis=1)

for_compare
# Out:
#                               all_averages  top_averages  bot_averages  \
# comp_pct                          0.049586      4.163708     -0.672644
# mark_down_amt_ty               2366.128483   2048.573704    705.051481
# payroll_adj_hours               138.139344    132.481481    110.555556
# strak_traffic                  1114.528013   1121.740741    418.370370
# strak_sales_amt               19672.463202  19227.620370   6289.053333
# special_order_amt              2663.678987   2842.442222    886.191481
# sales_value                   19671.135670  19211.477037   6257.581852
# shoes_units                      98.986761     90.851852     33.592593
# shoes_value                   12225.894484  11934.874074   4464.093333
# multi_value                    5255.678129   4945.428889   1717.817407
# payroll_units                   141.250395    135.175556    112.662222
# payroll_value                  2580.025921   2469.893704   1626.655185
# ...

# %% [markdown]
# ---
# ### Attempting to break up columns into different data sets below

# %%
pct = [name for name in df1.columns if name.endswith('PCT')]
amt = [name for name in df1.columns if name.endswith('AMT')]

# list(df.columns)

# %%
df1.store.mean?

# %%
# df1.info()
