# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from collections import Counter, OrderedDict
import IPython
from IPython.display import display, HTML
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"
# CSS = """
# .output {
#     flex-direction: row;
# }
# """
# HTML('<style>{}</style>'.format(CSS))
# pd.set_option('display.max_columns', None)

pd.set_option('display.max_columns', 50)

# %% [markdown]
# ---
#
# ## Further Practice
#
# ### REMEBER! This is not original data!. `_ly` columns dropped in notebook 3, outliers dropped, amongst other changes

# %%
df = pd.read_pickle('./data/0826export_mapped.pkl').iloc[:, 1:]
df.head(3)
# Out:
#    store week_end_date  fiscal_year  fiscal_week  fiscal_month  sales_amt_ty  \
# 0   1504     06-FEB-16         2017            1             1      22003.18
# 1   1504     13-FEB-16         2017            2             1      17499.35
# 2   1504     20-FEB-16         2017            3             1      15004.60
#
#    comp_pct  mark_down_amt_ty  payroll_adj_hours  num_of_days  strak_traffic  \
# 0  0.034622           1855.11                192            7           1168
# 1 -0.255050           1986.70                181            7            891
# 2 -0.327715           1331.95                183            7            930
#
#    strak_hrs  strak_sales_amt  strak_transaction_num  cp_valid_emails  \
# 0     186.88         22003.18                    114               51
# 1     180.31         17499.86                     94               33
# 2     182.23         15004.60                     79               39
#
#    cp_valid_mailing_address  cp_total_trans  cp_emails_per_trans  \
# 0                       105             121               0.7391
# 1                        74              94               0.5156
# 2                        65              78               0.6964
#
#    cp_mail_add_capture_rate  cp_email_mail_capture_rate  cp_total_email_trans  \
# 0                    0.8678                      0.8035                    69
# 1                    0.7872                      0.6514                    64
# 2                    0.8333                      0.7649                    56
#
#    special_order_amt  sales_units  sales_value  shoes_units  ...  \
# 0             892.46          296     22003.18           63  ...
# 1            1913.86          270     17499.35           54  ...
# 2            2799.29          211     15004.60           65  ...
#
#    sales_amt_per_pay_hour  mgr_count  mgr_tenure_days  avg_mgr_tenure_days  \
# 0              113.787971          1              286                286.0
# 1               96.542811          1              293                293.0
# 2               81.876023          1              300                300.0
#
#    am_count  am_tenure_days  avg_am_tenure_days  ft_count  ft_tenure_days  \
# 0         0               0                 0.0         2             934
# 1         0               0                 0.0         2             948
# 2         0               0                 0.0         2             962
#
#    avg_ft_tenure_days  pt_count  pt_tenure_days  avg_pt_tenure_days  \
# 0               467.0         1              47                47.0
# 1               474.0         1              54                54.0
# 2               481.0         1              61                61.0
#
#    num_of_emps  tot_tenure_days  tot_avg_tenure_days  open_date  close_date  \
# 0            4             1267                  317  01-MAY-12         NaN
# 1            4             1295                  324  01-MAY-12         NaN
# 2            4             1323                  331  01-MAY-12         NaN
#
#    store_state  store_city  gross_feet  class  rptcode  volume_band  \
# 0           NV   LAS VEGAS        1849   Mall       S             2
# 1           NV   LAS VEGAS        1849   Mall       S             2
# 2           NV   LAS VEGAS        1849   Mall       S             2
#
#    store_size
# 0         mdm
# 1         mdm
# 2         mdm
#
# [3 rows x 105 columns]

# %%
len(test.values)
# Out:
# 27189
